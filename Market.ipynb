# %% [markdown]
# # code : 148

# %%
# Analyzing and drawing the Graph of 'Open,Adj Close' at a Market dataset
# Detecting Noises & Missing values and Cleaning them

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data = pd.read_csv ('E:\Momeni-Machne Learning class momeni 21 01 1402\data science\datasets/Market.csv')
df=pd.DataFrame(data)
df
# Out:
#        Index        Date         Open         High          Low        Close  \
# 0        NYA  12/31/1965   528.690002   528.690002   528.690002   528.690002
# 1        NYA    1/3/1966   527.210022   527.210022   527.210022   527.210022
# 2        NYA    1/4/1966   527.840027   527.840027   527.840027   527.840027
# 3        NYA    1/5/1966   531.119995   531.119995   531.119995   531.119995
# 4        NYA    1/6/1966   532.070007   532.070007   532.070007   532.070007
# ...      ...         ...          ...          ...          ...          ...
# 112452  N100   5/27/2021  1241.119995  1251.910034  1241.119995  1247.069946
# 112453  N100   5/28/2021  1249.469971  1259.209961  1249.030029  1256.599976
# 112454  N100   5/31/2021  1256.079956  1258.880005  1248.140015  1248.930054
# 112455  N100    6/1/2021  1254.609985  1265.660034  1254.609985  1258.579956
# 112456  N100    6/2/2021  1258.489990  1263.709961  1258.239990  1263.619995
#
#           Adj Close       Volume
# ...

# %%
# We need Just These columns 'NYA', so delete other columns
df1 =  df[df['Index'] == 'NYA'] 
df1
# Out:
#       Index        Date          Open          High           Low  \
# 0       NYA  12/31/1965    528.690002    528.690002    528.690002
# 1       NYA    1/3/1966    527.210022    527.210022    527.210022
# 2       NYA    1/4/1966    527.840027    527.840027    527.840027
# 3       NYA    1/5/1966    531.119995    531.119995    531.119995
# 4       NYA    1/6/1966    532.070007    532.070007    532.070007
# ...     ...         ...           ...           ...           ...
# 13943   NYA   5/24/2021  16375.000000  16508.519530  16375.000000
# 13944   NYA   5/25/2021  16464.689450  16525.810550  16375.150390
# 13945   NYA   5/26/2021  16390.189450  16466.339840  16388.320310
# 13946   NYA   5/27/2021  16451.960940  16546.359380  16451.960940
# 13947   NYA   5/28/2021  16531.949220  16588.689450  16531.949220
#
#               Close     Adj Close        Volume
# 0        528.690002    528.690002  0.000000e+00
# 1        527.210022    527.210022  0.000000e+00
# ...

# %%
# Removing the last column because it is all zero
df2 = df1.drop(columns = 'Volume')
df2
# Out:
#       Index        Date          Open          High           Low  \
# 0       NYA  12/31/1965    528.690002    528.690002    528.690002
# 1       NYA    1/3/1966    527.210022    527.210022    527.210022
# 2       NYA    1/4/1966    527.840027    527.840027    527.840027
# 3       NYA    1/5/1966    531.119995    531.119995    531.119995
# 4       NYA    1/6/1966    532.070007    532.070007    532.070007
# ...     ...         ...           ...           ...           ...
# 13943   NYA   5/24/2021  16375.000000  16508.519530  16375.000000
# 13944   NYA   5/25/2021  16464.689450  16525.810550  16375.150390
# 13945   NYA   5/26/2021  16390.189450  16466.339840  16388.320310
# 13946   NYA   5/27/2021  16451.960940  16546.359380  16451.960940
# 13947   NYA   5/28/2021  16531.949220  16588.689450  16531.949220
#
#               Close     Adj Close
# 0        528.690002    528.690002
# 1        527.210022    527.210022
# 2        527.840027    527.840027
# ...

# %%
# Converting all floats to integers 
df3 = round(df2)
df3
# Out:
#       Index        Date     Open     High      Low    Close  Adj Close
# 0       NYA  12/31/1965    529.0    529.0    529.0    529.0      529.0
# 1       NYA    1/3/1966    527.0    527.0    527.0    527.0      527.0
# 2       NYA    1/4/1966    528.0    528.0    528.0    528.0      528.0
# 3       NYA    1/5/1966    531.0    531.0    531.0    531.0      531.0
# 4       NYA    1/6/1966    532.0    532.0    532.0    532.0      532.0
# ...     ...         ...      ...      ...      ...      ...        ...
# 13943   NYA   5/24/2021  16375.0  16509.0  16375.0  16465.0    16465.0
# 13944   NYA   5/25/2021  16465.0  16526.0  16375.0  16390.0    16390.0
# 13945   NYA   5/26/2021  16390.0  16466.0  16388.0  16452.0    16452.0
# 13946   NYA   5/27/2021  16452.0  16546.0  16452.0  16532.0    16532.0
# 13947   NYA   5/28/2021  16532.0  16589.0  16532.0  16556.0    16556.0
#
# [13948 rows x 7 columns]

# %%
# Sorting based on Date
df3.sort_values(by = 'Date')
# Out:
#       Index       Date     Open     High      Low    Close  Adj Close
# 6       NYA  1/10/1966    534.0    534.0    534.0    534.0      534.0
# 258     NYA  1/10/1967    477.0    477.0    477.0    477.0      477.0
# 510     NYA  1/10/1968    570.0    570.0    570.0    570.0      570.0
# 736     NYA  1/10/1969    604.0    604.0    604.0    604.0      604.0
# 1492    NYA  1/10/1972    604.0    604.0    604.0    604.0      604.0
# ...     ...        ...      ...      ...      ...      ...        ...
# 12255   NYA   9/9/2014  10994.0  10994.0  10923.0  10946.0    10946.0
# 12507   NYA   9/9/2015  10193.0  10220.0   9973.0   9989.0     9989.0
# 12760   NYA   9/9/2016  10799.0  10799.0  10614.0  10614.0    10614.0
# 13513   NYA   9/9/2019  12975.0  12975.0  12925.0  12961.0    12961.0
# 13766   NYA   9/9/2020  12806.0  12969.0  12804.0  12886.0    12886.0
#
# [13948 rows x 7 columns]

# %%
# Noise and error detection
df3.isnull().sum()
# Out:
# Index         0
# Date          0
# Open          1
# High          2
# Low           3
# Close         4
# Adj Close    10
# dtype: int64

# %%
# A Toral Cleaning of Mising Value 
df4 = df3.dropna()
df4
# Out:
#       Index        Date     Open     High      Low    Close  Adj Close
# 0       NYA  12/31/1965    529.0    529.0    529.0    529.0      529.0
# 1       NYA    1/3/1966    527.0    527.0    527.0    527.0      527.0
# 2       NYA    1/4/1966    528.0    528.0    528.0    528.0      528.0
# 3       NYA    1/5/1966    531.0    531.0    531.0    531.0      531.0
# 4       NYA    1/6/1966    532.0    532.0    532.0    532.0      532.0
# ...     ...         ...      ...      ...      ...      ...        ...
# 13943   NYA   5/24/2021  16375.0  16509.0  16375.0  16465.0    16465.0
# 13944   NYA   5/25/2021  16465.0  16526.0  16375.0  16390.0    16390.0
# 13945   NYA   5/26/2021  16390.0  16466.0  16388.0  16452.0    16452.0
# 13946   NYA   5/27/2021  16452.0  16546.0  16452.0  16532.0    16532.0
# 13947   NYA   5/28/2021  16532.0  16589.0  16532.0  16556.0    16556.0
#
# [13932 rows x 7 columns]

# %% [markdown]
# #  Identification and cleaning of noise of 'Open_Adj Close'

# %%
plt.figure(figsize =(10,8))
plt.scatter (df4['Open'], df4['Adj Close'])
plt.title('Open_Adj Close', fontsize= 30)
plt.xlabel('Open', fontsize=30)
plt.xticks(range(0,17000,1000))
plt.xticks(rotation=90)
plt.ylabel('Adj Close', fontsize = 30)
plt.yticks(range(0,17000,1000))
plt.legend(['show Open'], loc = 'best')
plt.grid()
plt.show()

# %%
# Below noise
Noise = df4[(df4['Open']>5000) & (df4['Adj Close']<1000)]
Noise
# Out:
#     Index       Date    Open   High    Low  Close  Adj Close
# 852   NYA  6/30/1969  5722.0  572.0  572.0  572.0      572.0

# %%
# second way 
Noise = df4[df4['Open']>5000]
Noise
# Out:
#       Index       Date     Open     High      Low    Close  Adj Close
# 852     NYA  6/30/1969   5722.0    572.0    572.0    572.0      572.0
# 7932    NYA   7/3/1997   5051.0   5051.0   5051.0   5051.0     5051.0
# 7933    NYA   7/7/1997   5028.0   5028.0   5028.0   5028.0     5028.0
# 7934    NYA   7/8/1997   5059.0   5059.0   5059.0   5059.0     5059.0
# 7935    NYA   7/9/1997   5002.0   5002.0   5002.0   5002.0     5002.0
# ...     ...        ...      ...      ...      ...      ...        ...
# 13943   NYA  5/24/2021  16375.0  16509.0  16375.0  16465.0    16465.0
# 13944   NYA  5/25/2021  16465.0  16526.0  16375.0  16390.0    16390.0
# 13945   NYA  5/26/2021  16390.0  16466.0  16388.0  16452.0    16452.0
# 13946   NYA  5/27/2021  16452.0  16546.0  16452.0  16532.0    16532.0
# 13947   NYA  5/28/2021  16532.0  16589.0  16532.0  16556.0    16556.0
#
# [5884 rows x 7 columns]

# %%
# upper noise
Noise2 = df4[(df4['Open']<1000) & (df4['Adj Close']>5000)]
Noise2
# Out:
#     Index       Date   Open   High    Low  Close  Adj Close
# 831   NYA  5/29/1969  612.0  612.0  612.0  612.0     6111.0

# %%
#  second way
Noise2 = df4[df4['Adj Close']>5000] 
Noise2
# Out:
#       Index       Date     Open     High      Low    Close  Adj Close
# 831     NYA  5/29/1969    612.0    612.0    612.0    612.0     6111.0
# 7932    NYA   7/3/1997   5051.0   5051.0   5051.0   5051.0     5051.0
# 7933    NYA   7/7/1997   5028.0   5028.0   5028.0   5028.0     5028.0
# 7934    NYA   7/8/1997   5059.0   5059.0   5059.0   5059.0     5059.0
# 7935    NYA   7/9/1997   5002.0   5002.0   5002.0   5002.0     5002.0
# ...     ...        ...      ...      ...      ...      ...        ...
# 13943   NYA  5/24/2021  16375.0  16509.0  16375.0  16465.0    16465.0
# 13944   NYA  5/25/2021  16465.0  16526.0  16375.0  16390.0    16390.0
# 13945   NYA  5/26/2021  16390.0  16466.0  16388.0  16452.0    16452.0
# 13946   NYA  5/27/2021  16452.0  16546.0  16452.0  16532.0    16532.0
# 13947   NYA  5/28/2021  16532.0  16589.0  16532.0  16556.0    16556.0
#
# [5884 rows x 7 columns]

# %%
# Deleting the detected noise
df4.drop(index = [831,852], inplace = True)
df4
# Out:
# C:\Users\zahra\AppData\Local\Temp\ipykernel_6760\2884223817.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df4.drop(index = [831,852], inplace = True)
#       Index        Date     Open     High      Low    Close  Adj Close
# 0       NYA  12/31/1965    529.0    529.0    529.0    529.0      529.0
# 1       NYA    1/3/1966    527.0    527.0    527.0    527.0      527.0
# 2       NYA    1/4/1966    528.0    528.0    528.0    528.0      528.0
# 3       NYA    1/5/1966    531.0    531.0    531.0    531.0      531.0
# 4       NYA    1/6/1966    532.0    532.0    532.0    532.0      532.0
# ...     ...         ...      ...      ...      ...      ...        ...
# 13943   NYA   5/24/2021  16375.0  16509.0  16375.0  16465.0    16465.0
# ...

# %% [markdown]
# #   Redraw the graph and check the removed noise

# %%
plt.figure(figsize =(10,8))
plt.scatter (df4['Open'], df4['Adj Close'])
plt.title('Open_Adj Close', fontsize= 30)
plt.xlabel('Open', fontsize=30)
plt.xticks(range(0,17000,1000))
plt.xticks(rotation=90)
plt.ylabel('Adj Close', fontsize = 30)
plt.yticks(range(0,17000,1000))
plt.legend(['show Open'], loc = 'best')
plt.grid()
plt.show()

# %% [markdown]
# # High_Adj Close : Noise detection and cleaning

# %%
plt.figure(figsize =(10,8))
plt.scatter (df4['High'], df4['Adj Close'])
plt.title('High_Adj Close', fontsize= 30)
plt.xlabel('High', fontsize=30)
plt.xticks(range(0,17000,1000))
plt.xticks(rotation=90)
plt.ylabel('Adj Close', fontsize = 30)
plt.yticks(range(0,17000,1000))
plt.legend(['show High'], loc = 'best')
plt.grid()
plt.show()

# %%
Noise_High = df4[(df4['High']>5000) & (df4['Adj Close']<1000)]
Noise_High
# Out:
#     Index       Date   Open    High    Low  Close  Adj Close
# 829   NYA  5/27/1969  612.0  6124.0  612.0  612.0      612.0
# 833   NYA   6/3/1969  607.0  6066.0  607.0  607.0      607.0

# %%
Noise_High = df4[df4['High']>5000]
Noise_High
# Out:
#       Index       Date     Open     High      Low    Close  Adj Close
# 829     NYA  5/27/1969    612.0   6124.0    612.0    612.0      612.0
# 833     NYA   6/3/1969    607.0   6066.0    607.0    607.0      607.0
# 7932    NYA   7/3/1997   5051.0   5051.0   5051.0   5051.0     5051.0
# 7933    NYA   7/7/1997   5028.0   5028.0   5028.0   5028.0     5028.0
# 7934    NYA   7/8/1997   5059.0   5059.0   5059.0   5059.0     5059.0
# ...     ...        ...      ...      ...      ...      ...        ...
# 13943   NYA  5/24/2021  16375.0  16509.0  16375.0  16465.0    16465.0
# 13944   NYA  5/25/2021  16465.0  16526.0  16375.0  16390.0    16390.0
# 13945   NYA  5/26/2021  16390.0  16466.0  16388.0  16452.0    16452.0
# 13946   NYA  5/27/2021  16452.0  16546.0  16452.0  16532.0    16532.0
# 13947   NYA  5/28/2021  16532.0  16589.0  16532.0  16556.0    16556.0
#
# [5896 rows x 7 columns]

# %%
# cleaning noise
df4.drop(index = [829,833], inplace = True)
df4
# Out:
# C:\Users\zahra\AppData\Local\Temp\ipykernel_6760\3022879551.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df4.drop(index = [829,833], inplace = True)
#       Index        Date     Open     High      Low    Close  Adj Close
# 0       NYA  12/31/1965    529.0    529.0    529.0    529.0      529.0
# 1       NYA    1/3/1966    527.0    527.0    527.0    527.0      527.0
# 2       NYA    1/4/1966    528.0    528.0    528.0    528.0      528.0
# 3       NYA    1/5/1966    531.0    531.0    531.0    531.0      531.0
# 4       NYA    1/6/1966    532.0    532.0    532.0    532.0      532.0
# ...     ...         ...      ...      ...      ...      ...        ...
# 13943   NYA   5/24/2021  16375.0  16509.0  16375.0  16465.0    16465.0
# ...

# %% [markdown]
# # Checking removed noise

# %%
plt.figure(figsize =(10,8))
plt.scatter (df4['High'], df4['Adj Close'])
plt.title('High_Adj Close', fontsize= 30)
plt.xlabel('High', fontsize=30)
plt.xticks(range(0,17000,1000))
plt.xticks(rotation=90)
plt.ylabel('Adj Close', fontsize = 30)
plt.yticks(range(0,17000,1000))
plt.legend(['show High'], loc = 'best')
plt.grid()
plt.show()

# %% [markdown]
# #  Low_Adj Close :  Noise detection and cleaning

# %%
plt.figure(figsize =(10,8))
plt.scatter (df4['Low'], df4['Adj Close'])
plt.title('Low_Adj Close', fontsize= 30)
plt.xlabel('Low', fontsize=30)
plt.xticks(range(0,17000,1000))
plt.xticks(rotation=90)
plt.ylabel('Adj Close', fontsize = 30)
plt.yticks(range(0,17000,1000))
plt.legend(['show Low'], loc = 'best')
plt.grid()
plt.show()

# %%
Noise_Low = df4[(df4['Low']<1000) & (df4['Adj Close']>6000)]
Noise_Low
# Out:
# Empty DataFrame
# Columns: [Index, Date, Open, High, Low, Close, Adj Close]
# Index: []

# %%
# اینجا دیگه نویز نشون نمیده 
# قبل از پاکسازی نویز ستون های قبل این نویز داره ولی بعدش نویزهای این هم پاک میشه

# %% [markdown]
# # Close_Adj Close : Noise detection and cleaning

# %%
plt.figure(figsize =(10,8))
plt.scatter (df4['Low'], df4['Adj Close'])
plt.title('Close_Adj Close', fontsize= 30)
plt.xlabel('Close', fontsize=30)
plt.xticks(range(0,17000,1000))
plt.xticks(rotation=90)
plt.ylabel('Adj Close', fontsize = 30)
plt.yticks(range(0,17000,1000))
plt.legend(['show Close'], loc = 'best')
plt.grid()
plt.show()

# %%
# This also has no noise
